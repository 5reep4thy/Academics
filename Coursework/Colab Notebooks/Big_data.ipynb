# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
f = open("/content/Invistico_Airline.csv")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='/content/Invistico_Airline.csv' mode='r' encoding='UTF-8'>
